# %%
import numpy as np # linear algebra

import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
os.chmod(r'C:\Users\Khanjan\Desktop\project2\crop_yield.csv',0o444)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Khanjan\Desktop\project2\crop_yield.csv')
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
df=df.drop(['Production','Pesticide'],axis=1)

# %%
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Annual_Rainfall   Fertilizer        Yield
# ...

# %%
df.shape
# Out:
# (19689, 8)

# %%
df.isnull().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Annual_Rainfall    0
# Fertilizer         0
# Yield              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#           Crop_Year          Area  Annual_Rainfall    Fertilizer         Yield
# count  19689.000000  1.968900e+04     19689.000000  1.968900e+04  19689.000000
# mean    2009.127584  1.799266e+05      1437.755177  2.410331e+07     79.954009
# std        6.498099  7.328287e+05       816.909589  9.494600e+07    878.306193
# min     1997.000000  5.000000e-01       301.300000  5.417000e+01      0.000000
# 25%     2004.000000  1.390000e+03       940.700000  1.880146e+05      0.600000
# 50%     2010.000000  9.317000e+03      1247.600000  1.234957e+06      1.030000
# 75%     2015.000000  7.511200e+04      1643.700000  1.000385e+07      2.388889
# max     2020.000000  5.080810e+07      6552.700000  4.835407e+09  21105.000000

# %%
allstates=(df['State'].unique())

# %%
yield_per_state=[]
for state in allstates:
     yield_per_state.append(df[df['State']==state]['Yield'].sum())

# %%
crops=(df['Crop'].unique())

# %%
yield_per_crop = []
for crop in crops:
    yield_per_crop.append(df[df['Crop']==crop]['Yield'].sum())

# %%
X = df.drop('Yield',axis=1)
y= df['Yield']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0, shuffle=True)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
ohe = OneHotEncoder(drop='first',handle_unknown='ignore')
scale = StandardScaler()

preprocesser = ColumnTransformer(
        transformers = [
            ('StandardScale', scale, [1,4,5,6]),
            ('OHE', ohe, [0,2,3]),
        ],
        remainder='passthrough'
)

# %%
preprocesser
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('StandardScale', StandardScaler(),
#                                  [1, 4, 5, 6]),
#                                 ('OHE',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore'),
#                                  [0, 2, 3])])

# %%
X_train_dummy = preprocesser.fit_transform(X_train)
X_test_dummy = preprocesser.transform(X_test)

# %%
#linear regression
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error,r2_score


models = {
    'lr':LinearRegression(),
    'lss':Lasso(),
    'Rid':Ridge(),
    'Dtr':DecisionTreeRegressor()
}
for name, md in models.items():
    md.fit(X_train_dummy,y_train)
    y_pred = md.predict(X_test_dummy)
    
    print(f"{name} : mae : {mean_absolute_error(y_test,y_pred)} score : {r2_score(y_test,y_pred)}")
# Out:
# lr : mae : 99.53405756148543 score : 0.299441757417898
# lss : mae : 47.14493960520778 score : 0.84290590724558
# Rid : mae : 98.93537680977354 score : 0.2990311987998774
# Dtr : mae : 7.552105528213052 score : 0.9708785005695139

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train_dummy,y_train)
dtr.predict(X_test_dummy)
# Out:
# array([37.17272727,  5.57851852,  0.722     , ...,  3.41074074,
#         4.57833333,  1.734     ])

# %%
def prediction(Crop,Crop_Year,Season,State,Area,Annual_Rainfall,Fertilizer):
    # Create an array of the input features
    features = np.array([[Crop,Crop_Year,Season,State,Area,Annual_Rainfall,Fertilizer]], dtype=object)

    # Transform the features using the preprocessor
    transformed_features = preprocesser.transform(features)

    # Make the prediction
    predicted_yield = dtr.predict(transformed_features).reshape(1, -1)

    return predicted_yield[0]

Crop = 'Arecanut'			
Crop_Year = 1997
Season = 'Whole Year'
State = 'Assam'
Area=73814.0	
Annual_Rainfall=2051.4
Fertilizer=7024878.38
result = prediction(Crop,Crop_Year,Season,State,Area,Annual_Rainfall,Fertilizer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 20
#      18 Annual_Rainfall=2051.4
#      19 Fertilizer=7024878.38
# ---> 20 result = prediction(Crop,Crop_Year,Season,State,Area,Annual_Rainfall,Fertilizer)
#
# Cell In[73], line 6, in prediction(Crop, Crop_Year, Season, State, Area, Annual_Rainfall, Fertilizer)
#       3 features = np.array([[Crop,Crop_Year,Season,State,Area,Annual_Rainfall,Fertilizer]], dtype=object)
#       5 # Transform the features using the preprocessor
# ----> 6 transformed_features = preprocesser.transform(features)
#       8 # Make the prediction
#       9 predicted_yield = dtr.predict(transformed_features).reshape(1, -1)
#
# ...

# %%
result
# Out:
# array([0.79608696])

# %%
import pickle
pickle.dump(dtr,open('decisiontree.pkl','wb'))
pickle.dump(preprocesser,open('preprocessor1.pkl','wb'))
